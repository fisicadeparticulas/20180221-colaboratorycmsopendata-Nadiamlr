# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import math

# %matplotlib inline

# %%
muons = pd.read_csv('http://opendata.cern.ch/record/545/files/Dimuon_DoubleMu.csv')
muons.head()
# Out:
#       Run     Event type1       E1     px1     py1      pz1     pt1    eta1  \
# 0  165617  74601703     G   9.6987 -9.5104  0.3662   1.8633  9.5175  0.1945
# 1  165617  75100943     G   6.2039 -4.2666  0.4565  -4.4793  4.2910 -0.9121
# 2  165617  75587682     G  19.2892 -4.2121 -0.6516  18.8121  4.2622  2.1905
# 3  165617  75660978     G   7.0427 -6.3268 -0.2685   3.0802  6.3325  0.4690
# 4  165617  75947690     G   7.2751  0.1030 -5.5331  -4.7212  5.5340 -0.7736
#
#      phi1   ...     type2      E2     px2     py2     pz2     pt2    eta2  \
# 0  3.1031   ...         G  9.7633  7.3277 -1.1524  6.3473  7.4178  0.7756
# 1  3.0350   ...         G  9.6690  7.2740 -2.8211 -5.7104  7.8019 -0.6786
# 2 -2.9881   ...         G  9.8244  4.3439 -0.4735  8.7985  4.3697  1.4497
# 3 -3.0992   ...         G  5.5857  4.4748  0.8489 -3.2319  4.5546 -0.6605
# 4 -1.5522   ...         G  7.3181 -0.3988  6.9408  2.2825  6.9523  0.3227
#
#      phi2  Q2        M
# 0 -0.1560   1  17.4922
# ...

# %%
len(muons)
# Out:
# 100000

# %%
fig = plt.figure(figsize=(15, 10))

plt.hist(muons.M, 300, range = (0,150))

plt.xlabel('Invariant mass (GeV/$c^2$)', fontsize = 15)
plt.ylabel('Number of events \n', fontsize = 15)
plt.title('Measured distribution of events with two muons \n', fontsize = 15)

plt.show()

# %%
bump = muons[(muons.M >= 80) & (muons.M <= 100)]

fig = plt.figure(figsize=(15, 10))

plt.hist(bump.M, 300, range = (80,100))

plt.xlabel('Invariant mass (GeV/$c^2$)', fontsize = 15)
plt.ylabel('Number of events \n', fontsize = 15)
plt.title('Measured distribution of events with two muons \n', fontsize = 15)

plt.show()

# %%
sample7 = pd.read_csv('https://goo.gl/PU9w7m')
sample7.head()
# Out:
#       Run      Event      pt1    eta1    phi1  Q1 type1  sigmaEtaEta1  \
# 0  163286  109060857  37.5667  2.2892  2.0526  -1    EE        0.0251
# 1  163286  109275715  36.2901 -0.8373 -1.5859   1    EB        0.0078
# 2  163286  109075352  25.9705 -0.6974  1.6360  -1    EB        0.0097
# 3  163286  109169766  41.0075  1.4619 -0.5325   1    EB        0.0088
# 4  163286  108947653  39.8985 -0.5927 -2.3947   1    EB        0.0153
#
#    HoverE1  isoTrack1    ...         pt2    eta2    phi2  Q2  type2  \
# 0   0.0090     0.0000    ...     45.4315  1.4706 -1.1630   1     EB
# 1   0.0438     0.0000    ...     60.5754 -0.4896  1.0496  -1     EB
# 2   0.0407     6.2870    ...     45.2954 -2.0401  3.1187   1     EE
# 3   0.0000     0.0000    ...     45.9013  1.1561  2.4786  -1     EB
# 4   0.0000     2.5435    ...     34.8931 -2.2444  0.6106  -1     EE
#
#    sigmaEtaEta2 HoverE2  isoTrack2  isoEcal2  isoHcal2
# 0        0.0008   0.000     0.0000    1.0190    0.0000
# ...

# %%
invariant_mass = np.sqrt(2*sample7.pt1*sample7.pt2*(np.cosh(sample7.eta1-sample7.eta2) - np.cos(sample7.phi1-sample7.phi2)))

# %%
print(invariant_mass)
# Out:
# 0        89.590677
# 1        92.252203
# 2        67.859050
# 3        87.604679
# 4       101.424147
# 5       119.556558
# 6       107.429228
# 7       102.347597
# 8       107.870440
# 9        82.869840
# 10       63.908579
# 11       85.501235
# 12       94.537894
# 13       85.235855
# 14       94.448496
# 15      106.953341
# 16       84.418848
# 17       99.225378
# 18      108.762598
# 19       74.474242
# 20       73.983022
# 21       95.949937
# 22       89.337543
# 23      111.547215
# 24       78.960451
# 25      103.036991
# 26       97.732245
# 27      109.010022
# 28       80.674175
# 29       92.680930
#            ...
# 9970     92.555548
# 9971     88.385460
# 9972     89.597977
# 9973    108.015079
# 9974    105.830551
# 9975     92.548610
# 9976     89.687072
# 9977     92.188974
# 9978     64.244697
# 9979    101.541228
# 9980     86.511852
# 9981    113.767201
# 9982     90.055164
# 9983     93.966533
# 9984     67.417229
# 9985     91.467377
# ...

# %%
fig = plt.figure(figsize=(15, 10))

plt.hist(invariant_mass, 300, range = (0,150))

plt.xlabel('Invariant mass (GeV/$c^2$)', fontsize = 20)
plt.ylabel('Number of events \n', fontsize = 20)
plt.title('Invariant mass for Z → e + e − \n', fontsize = 20)

plt.show()

# %%
delPhi =np.abs(sample7.phi1-sample7.phi2)

# %%
print(delPhi)
# Out:
# 0       3.2156
# 1       2.6355
# 2       1.4827
# 3       3.0111
# 4       3.0053
# 5       2.8354
# 6       3.2327
# 7       0.9959
# 8       2.7462
# 9       3.4189
# 10      3.3169
# 11      3.3011
# 12      2.6327
# 13      3.1064
# 14      3.2202
# 15      3.1185
# 16      3.5665
# 17      3.2073
# 18      3.0206
# 19      3.2820
# 20      3.7078
# 21      3.0743
# 22      3.0765
# 23      3.2110
# 24      3.1750
# 25      3.2530
# 26      3.6084
# 27      3.5398
# 28      3.8790
# 29      3.1251
#          ...
# 9970    3.0680
# 9971    2.9662
# 9972    3.3742
# 9973    3.0462
# 9974    2.7314
# 9975    2.7476
# 9976    3.0865
# 9977    3.1841
# 9978    3.3597
# 9979    4.0933
# 9980    3.1129
# 9981    2.9292
# 9982    3.0602
# 9983    3.2308
# 9984    2.9457
# 9985    3.1919
# 9986    2.7107
# 9987    3.0575
# 9988    2.5281
# 9989    3.4707
# 9990    2.9666
# 9991    3.0624
# 9992    3.4060
# 9993    2.5358
# 9994    3.1916
# 9995    3.3451
# 9996    3.0605
# ...

# %%
fig = plt.figure(figsize=(15, 10))

plt.hist(delPhi, 300, range = (0,8),color='blue')

plt.xlabel('Delta Phi', fontsize = 20)
plt.ylabel('Number of events \n', fontsize = 20)
plt.title('Delta Phi', fontsize = 20)

plt.show()

# %%
mass = np.sqrt(2*sample7.pt1*sample7.pt2*(np.cosh(sample7.eta1-sample7.eta2) - np.cos(delPhi)))
s=[]

for i in range(0,len(mass)):
  if delPhi[i]<math.pi:
    s.append(mass[i])
    
fig = plt.figure(figsize=(15, 10))

plt.hist(s, 300, range = (0,150), color='mediumseagreen')

plt.xlabel('Invariant mass (GeV/$c^2$)', fontsize = 20)
plt.ylabel('Number of events \n', fontsize = 20)
plt.title('Measured distribution of events with two electrons \n', fontsize = 20)

plt.show()

# %%
len(s)
# Out:
# 5377

# %%
fig = plt.figure(figsize=(15, 10))

plt.hist(sample7.eta1, 300, range = (-4,4), color='orange')

plt.xlabel('Eta1', fontsize = 20)
plt.ylabel('Number of events \n', fontsize = 20)
plt.title('Eta distribution of the first set of electrons \n', fontsize = 20)

plt.show()

# %%
fig = plt.figure(figsize=(15, 10))

plt.hist(sample7.eta2, 300, range = (-4,4), color='coral')

plt.xlabel('Eta2', fontsize = 20)
plt.ylabel('Number of events \n', fontsize = 20)
plt.title('Eta distribution of the second set of electrons \n', fontsize = 20)

plt.show()

# %%
isoT=sample7.isoTrack1+sample7.isoTrack2

# %%
fig = plt.figure(figsize=(15, 10))

plt.hist(isoT, 300, range = (0,150), color='orange')

plt.xlabel('IsoTrack', fontsize = 20)
plt.ylabel('Number of events \n', fontsize = 20)
plt.title('Isolation in the Tracker \n', fontsize = 20)

plt.show()

# %%
Pt=sample7.pt1+sample7.pt2

# %%
rel_isoT=isoT/Pt

# %%
fig = plt.figure(figsize=(15, 10))

plt.hist(rel_isoT, 300, range = (0,1.3), color='cadetblue')

plt.xlabel('Relative Isolation in the Tracker', fontsize = 20)
plt.ylabel('Number of events \n', fontsize = 20)
plt.title('Relative Isolation in the Tracker \n', fontsize = 20)

plt.show()

# %%
isoE=sample7.isoEcal1+sample7.isoEcal2

# %%
fig = plt.figure(figsize=(15, 10))

plt.hist(isoE, 300, range = (0,100), color='hotpink')

plt.xlabel('Isolation in the ECAL', fontsize = 20)
plt.ylabel('Number of events \n', fontsize = 20)
plt.title('Isolation in the ECAL \n', fontsize = 20)

plt.show()

# %%
rel_isoE=isoE/Pt

# %%
fig = plt.figure(figsize=(15, 10))

plt.hist(rel_isoE, 300, range = (0,2), color='pink')

plt.xlabel('Relative Isolation in the ECAL', fontsize = 20)
plt.ylabel('Number of events \n', fontsize = 20)
plt.title('Relative Isolation in the ECAL \n', fontsize = 20)

plt.show()

# %%
isoH=sample7.isoHcal1+sample7.isoHcal2

# %%
fig = plt.figure(figsize=(15, 10))

plt.hist(isoH, 300, range = (0,100), color='purple')

plt.xlabel('Isolation in the HCAL', fontsize = 20)
plt.ylabel('Number of events \n', fontsize = 20)
plt.title('Isolation in the HCAL \n', fontsize = 20)

plt.show()

# %%
rel_isoH=isoH/Pt

# %%
fig = plt.figure(figsize=(15, 10))

plt.hist(rel_isoH, 300, range = (0,1), color='hotpink')

plt.xlabel('Relative Isolation in the HCAL', fontsize = 20)
plt.ylabel('Number of events \n', fontsize = 20)
plt.title(' Relative Isolation in the HCAL \n', fontsize = 20)

plt.show()

# %%
fig = plt.figure(figsize=(15, 10))

plt.hist(sample7.sigmaEtaEta1, 300, range = (0,0.075), color='gold')

plt.xlabel('sigmaEtaEta1', fontsize = 20)
plt.ylabel('Number of events \n', fontsize = 20)
plt.title(' sigmaEtaEta for the first set of electrons', fontsize = 20)

plt.show()

# %%
fig = plt.figure(figsize=(15, 10))

plt.hist(sample7.sigmaEtaEta2, 300, range = (0,0.1), color='lawngreen')

plt.xlabel('sigmaEtaEta2', fontsize = 20)
plt.ylabel('Number of events \n', fontsize = 20)
plt.title(' sigmaEtaEta for the second set of electrons', fontsize = 20)

plt.show()

# %%
invmass = np.sqrt(2*sample7.pt1*sample7.pt2*(np.cosh(sample7.eta1-sample7.eta2) - np.cos(delPhi)))
l=[]

for i in range(0,len(mass)):
  if delPhi[i]<math.pi and rel_isoT[i]<0.2 and rel_isoE[i]<0.5 and rel_isoH[i]<0.2 and np.abs(sample7.eta1[i])<2.4 and np.abs(sample7.eta2[i])<2.4 and sample7.sigmaEtaEta1[i]<0.02 and sample7.sigmaEtaEta2[i]<0.02:
    l.append(invmass[i])
    
fig = plt.figure(figsize=(15, 10))

plt.hist(l, 300, range = (0,150), color='mediumseagreen')

plt.xlabel('Invariant mass (GeV/$c^2$)', fontsize = 20)
plt.ylabel('Number of events \n', fontsize = 20)
plt.title('Measured distribution of events with two electrons \n', fontsize = 20)

plt.show()

# %%
len(l)
# Out:
# 2811
